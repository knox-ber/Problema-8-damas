# %% [markdown]
# # Proyecto de Lógica para Ciencias de la Computación
# ## __G01__

# %%
from Damas import *

# %%
d = Damas(F=8,C=8)

# %% [markdown]
# __Nota importante:__ $Damas.py$ ya importa el archivo $Logica.py$
#
# __Nota importante #2:__ El método $SATtableaux()$ está implementado con __BACKTRACKING__

# %% [markdown]
# ## **SATtableaux()**

# %% [markdown]
# ### Regla 1

# %%
# %%time
A = inorder_to_tree(d.regla1())
# print(A)

I = A.SATtableaux()
d.visualizar(I)
# Out:
# CPU times: total: 78.1 ms
# Wall time: 312 ms

# %% [markdown]
# ### Regla 2

# %%
# %%time
B = inorder_to_tree(d.regla2())
# print(B)

I = B.SATtableaux()
d.visualizar(I)
# Out:
# CPU times: total: 969 ms
# Wall time: 1.2 s

# %% [markdown]
# ### Regla 3

# %%
# %%time
C = inorder_to_tree(d.regla3())
# print(C)

I = C.SATtableaux()
d.visualizar(I)
# Out:
# CPU times: total: 1.06 s
# Wall time: 1.29 s

# %% [markdown]
# ### Regla 4

# %%
# %%time
D = inorder_to_tree(d.regla4())
# print(D)

I = D.SATtableaux()
d.visualizar(I)
# Out:
# CPU times: total: 1.19 s
# Wall time: 1.42 s

# %% [markdown]
# ### Ytoria

# %%
# %%time
Y = inorder_to_tree(Ytoria(d.reglas))
# print(Y)

I = Y.SATtableaux()
d.visualizar(I)
