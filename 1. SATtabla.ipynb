# %% [markdown]
# # Proyecto de Lógica para Ciencias de la Computación
# ## __G01__

# %%
from Damas import *

# %%
d = Damas(F=8,C=8)

# %% [markdown]
# __Nota importante:__ $Damas.py$ ya importa el archivo $Logica.py$

# %% [markdown]
# ## **SATtabla()**
# Este SAT solver NO es capaz de correr ninguna regla.

# %% [markdown]
# ### Regla 1

# %%
# %%time
A = inorder_to_tree(d.regla1())
print(A)

I = A.SATtabla()
d.visualizar(I)

# %% [markdown]
# ### Regla 2

# %%
# %%time
B = inorder_to_tree(d.regla2())
print(B)

I = B.SATtabla()
d.visualizar(I)

# %% [markdown]
# ### Regla 3

# %%
# %%time
C = inorder_to_tree(d.regla3())
print(C)

I = C.SATtabla()
d.visualizar(I)

# %% [markdown]
# ### Regla 4

# %%
# %%time
D = inorder_to_tree(d.regla4())
print(D)

I = D.SATtabla()
d.visualizar(I)

# %% [markdown]
# ### Ytoria

# %%
# %%time
Y = inorder_to_tree(Ytoria(d.reglas))
print(Y)

I = Y.SATtabla()
d.visualizar(I)
