# %% [markdown]
# # Proyecto de Lógica para Ciencias de la Computación
# ## __G01__

# %%
from Damas import *

# %%
d = Damas(F=8,C=8)

# %% [markdown]
# __Nota importante:__ $Damas.py$ ya importa el archivo $Logica.py$
#
# __Nota importante #2:__ El método $walkSAT()$ está implementado con un $max\_flips=1000$, $max\_tries=100$, y $p=0.5$.

# %% [markdown]
# ## **walkSAT()**
# Este SAT solver solo es capaz de correr la Regla 1.

# %% [markdown]
# ### Regla 1

# %%
# %%time
A = tseitin(d.regla1())
# print(A)

S, I = walkSAT(A)
# print(I)
d.visualizar(I)
# Out:
# CPU times: total: 172 ms
# Wall time: 8.9 s

# %% [markdown]
# ### Regla 2

# %%
# %%time
B = tseitin(d.regla2())
# print(B)

I = walkSAT(B)
# print(I)
#d.visualizar(I)

# %% [markdown]
# ### Regla 3

# %%
# %%time
C = tseitin(d.regla3())
# print(C)

I = walkSAT(C)
# print(I)
#d.visualizar(I)

# %% [markdown]
# ### Regla 4

# %%
# %%time
D = tseitin(d.regla4())
# print(D)

I = walkSAT(D)
# print(I)
#d.visualizar(I)

# %% [markdown]
# ### Ytoria

# %%
# %%time
Y = tseitin(Ytoria(d.reglas))
# print(Y)

I = walkSAT(Y)
# print(I)
#d.visualizar(I)
